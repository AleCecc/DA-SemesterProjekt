# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import pandas as pd
from IPython.display import clear_output
from pandas.io.json import json_normalize


# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="car"](area);
        out;"""


# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('carvendors.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)
df.head(5)
# Out:
#    type         id        lat       lon tags.addr:city tags.addr:housenumber  \
# 0  node   56699071  47.234366  8.735632          Stäfa                   155
# 1  node  112017810  47.350203  8.527605         Zürich                     4
# 2  node  246658345  47.229552  8.962142            NaN                   NaN
# 3  node  259589969  47.029684  8.294093            NaN                   NaN
# 4  node  274592776  47.489136  7.595573            NaN                   NaN
#
#   tags.addr:postcode tags.addr:street                     tags.brand  \
# 0               8712       Seestrasse                          Škoda
# 1               8038     Thujastrasse  Abarth;Alfa Romeo;Fiat;Lancia
# 2                NaN              NaN                            NaN
# 3                NaN              NaN                         Toyota
# 4                NaN              NaN                            NaN
#
#   tags.brand:wikidata  ... tags.operator:website tags.office  \
# 0              Q29637  ...                   NaN         NaN
# 1                 NaN  ...                   NaN         NaN
# 2                 NaN  ...                   NaN         NaN
# 3              Q53268  ...                   NaN         NaN
# 4                 NaN  ...                   NaN         NaN
#
#   tags.payment:cards tags.payment:invoice tags.service:vehicle:Sale  \
# 0                NaN                  NaN                       NaN
# 1                NaN                  NaN                       NaN
# 2                NaN                  NaN                       NaN
# 3                NaN                  NaN                       NaN
# 4                NaN                  NaN                       NaN
#
#   tags.opening_hours:signed tags.addr:full tags.payment:coins  \
# 0                       NaN            NaN                NaN
# 1                       NaN            NaN                NaN
# 2                       NaN            NaN                NaN
# 3                       NaN            NaN                NaN
# 4                       NaN            NaN                NaN
#
#   tags.payment:postfinance_card tags.mobile
# 0                           NaN         NaN
# 1                           NaN         NaN
# 2                           NaN         NaN
# 3                           NaN         NaN
# 4                           NaN         NaN
#
# [5 rows x 143 columns]

# %%
# Subset of supermarkets by brand
loc2= df[["lat", "lon", "tags.brand", "tags.addr:housenumber","tags.addr:street","tags.name"]]

loc2=loc2.rename(columns={"tags.brand": "brand", "tags.addr:housenumber": "housenumber", "tags.addr:street":"street", "tags.name": "name"})

print(loc2)
# Out:
#            lat       lon                          brand housenumber  \
# 0    47.234366  8.735632                          Škoda         155
# 1    47.350203  8.527605  Abarth;Alfa Romeo;Fiat;Lancia           4
# 2    47.229552  8.962142                            NaN         NaN
# 3    47.029684  8.294093                         Toyota         NaN
# 4    47.489136  7.595573                            NaN         NaN
# ..         ...       ...                            ...         ...
# 945  46.589044  7.084241             Mitsubishi;Hyundai         NaN
# 946  47.229561  8.843061                            NaN         NaN
# 947  47.028329  8.631441                Hyundai;Citroen         NaN
# 948  47.388597  9.651213                     Volkswagen         NaN
# 949  47.228935  8.846548                            NaN         NaN
#
#            street                 name
# 0      Seestrasse   Seegarage Stäfa AG
# 1    Thujastrasse     Kalchbühl-Garage
# 2             NaN                  NaN
# 3             NaN       Schwerzmann AG
# 4             NaN  Garage B. Schmid AG
# ..            ...                  ...
# 945           NaN   Garage de la Forge
# 946           NaN    Auto Trachsler AG
# 947           NaN      Auto Heinzer AG
# 948           NaN           volkswagen
# 949           NaN   Heusser Automobile
#
# [950 rows x 6 columns]

# %%
# Remove duplicates
loc2 = loc2.drop_duplicates()

# Remove missing values
loc2 = loc2.dropna()

print(loc2)
# Out:
#            lat       lon                          brand housenumber  \
# 0    47.234366  8.735632                          Škoda         155
# 1    47.350203  8.527605  Abarth;Alfa Romeo;Fiat;Lancia           4
# 34   47.174636  7.540673                      Le Garage          32
# 37   47.190774  7.553083                          Volvo           1
# 50   47.040624  7.624709                        Peugeot           1
# ..         ...       ...                            ...         ...
# 913  47.377901  8.511583                  Renault;Dacia         330
# 920  46.248107  6.955989               Kia, Opel, Isuzu          34
# 921  46.955450  8.334331                        Peugeot           4
# 925  47.373732  8.537498                       Polestar           9
# 933  47.641201  9.199856            Opel Hyundai Suzuki          89
#
#                 street                       name
# 0           Seestrasse         Seegarage Stäfa AG
# 1         Thujastrasse           Kalchbühl-Garage
# 34    Heinibühlstrasse               Moby Campers
# 37       Aesplistrasse           Viatte-Straub AG
# 50     Emmentalstrasse               Von Ballmoos
# ..                 ...                        ...
# 913     Badenerstrasse                 RRG Suisse
# 920  Avenue du Simplon  Garage des Sports Monthey
# 921         Talstrasse               VM Cars GmbH
# 925        Sihlstrasse                   Polestar
# 933      Seetalstrasse          Heller Automobile
#
# [128 rows x 6 columns]

# %%
import sqlite3
import fnmatch
import os

# Create data base
conn = sqlite3.connect('vendors.db')
cursor = conn.cursor()

# Show dbs in the directory
flist = fnmatch.filter(os.listdir('.'), '*.db')
for i in flist:
    print(i)
# Out:
# vendors.db
# Zurich.db

# %%
#create SQL table in the database

cursor.execute('''CREATE TABLE IF NOT EXISTS vendors_table (lat DECIMAL(2,13),
                                                                lon DECIMAL(2,13),
                                                                Brand VARCHAR(100),
                                                                Housenumber INT(4),
                                                                Street VARCHAR(50),
                                                                Vendorname VARCHAR(50))''')
# Confirm changes to the table
conn.commit()

# %%
#Write data to the SQL-table in data base
loc2.to_sql(name = 'vendors_table',
            con = conn,
         index = False,
         if_exists = 'replace')
# Out:
# 128

# %%
# Create map
map = folium.Map(loc2=[loc2.lat.mean(), 
                           loc2.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, loc2_info in loc2.iterrows():
    folium.Marker([loc2_info["lat"], 
                   loc2_info["lon"]], 
                  popup=loc2_info["name"]).add_to(map)

# Plot map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94f113657312670a2a779182fcdf7dea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94f113657312670a2a779182fcdf7dea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_94f113657312670a2a779182fcdf7dea = L.map(
#                 &quot;map_94f113657312670a2a779182fcdf7dea&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     loc2: [47.14739325625, 8.196173560937499],
#                 }
#             );
#             L.control.scale().addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#
#
#
#             var tile_layer_b0fdb05459ee4ace765089c9b2de7fb6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#             var marker_d80a5b6a0c58ce3f4185b66ac9af6deb = L.marker(
#                 [47.234366, 8.7356323],
#                 {}
#             ).addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#         var popup_9f0a2e856f6dd06175b14bca321507ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8d04783ae639c8adb78195113a25f205 = $(`&lt;div id=&quot;html_8d04783ae639c8adb78195113a25f205&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Seegarage Stäfa AG&lt;/div&gt;`)[0];
#             popup_9f0a2e856f6dd06175b14bca321507ed.setContent(html_8d04783ae639c8adb78195113a25f205);
#
#
#         marker_d80a5b6a0c58ce3f4185b66ac9af6deb.bindPopup(popup_9f0a2e856f6dd06175b14bca321507ed)
#         ;
#
#
#
#
#             var marker_8481cecd1e9ac1861ac5f94f74949ed1 = L.marker(
#                 [47.3502028, 8.5276055],
#                 {}
#             ).addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#         var popup_b16c46771529d79d7e75a0f08c460c71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cdfd4f1261392079f05c2c82e07984c8 = $(`&lt;div id=&quot;html_cdfd4f1261392079f05c2c82e07984c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kalchbühl-Garage&lt;/div&gt;`)[0];
#             popup_b16c46771529d79d7e75a0f08c460c71.setContent(html_cdfd4f1261392079f05c2c82e07984c8);
#
#
#         marker_8481cecd1e9ac1861ac5f94f74949ed1.bindPopup(popup_b16c46771529d79d7e75a0f08c460c71)
#         ;
#
#
#
#
#             var marker_3f53ce999e26b839a52a3d04103e9866 = L.marker(
#                 [47.174636, 7.5406729],
#                 {}
#             ).addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#         var popup_009d76e0fbd7ffbc636403cfec6a519c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c824e2db741c98b95de8570a742544f3 = $(`&lt;div id=&quot;html_c824e2db741c98b95de8570a742544f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Moby Campers&lt;/div&gt;`)[0];
#             popup_009d76e0fbd7ffbc636403cfec6a519c.setContent(html_c824e2db741c98b95de8570a742544f3);
#
#
#         marker_3f53ce999e26b839a52a3d04103e9866.bindPopup(popup_009d76e0fbd7ffbc636403cfec6a519c)
#         ;
#
#
#
#
#             var marker_09d6d47e50991fc24e9ae5e4743996a6 = L.marker(
#                 [47.1907736, 7.5530826],
#                 {}
#             ).addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#         var popup_7c62c38181859814f42aea6d6e1ddb2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b758956a422723d11ce16d1abdb950e5 = $(`&lt;div id=&quot;html_b758956a422723d11ce16d1abdb950e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viatte-Straub AG&lt;/div&gt;`)[0];
#             popup_7c62c38181859814f42aea6d6e1ddb2a.setContent(html_b758956a422723d11ce16d1abdb950e5);
#
#
#         marker_09d6d47e50991fc24e9ae5e4743996a6.bindPopup(popup_7c62c38181859814f42aea6d6e1ddb2a)
#         ;
#
#
#
#
#             var marker_7c3b11d83fc5edf9e062d1b7a74dec8c = L.marker(
#                 [47.040624, 7.6247094],
#                 {}
#             ).addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#         var popup_586eccad65f6c89d44e8e84bb8161239 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3f1adfe2712a3d36fff2957ca2747e3d = $(`&lt;div id=&quot;html_3f1adfe2712a3d36fff2957ca2747e3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Von Ballmoos&lt;/div&gt;`)[0];
#             popup_586eccad65f6c89d44e8e84bb8161239.setContent(html_3f1adfe2712a3d36fff2957ca2747e3d);
#
#
#         marker_7c3b11d83fc5edf9e062d1b7a74dec8c.bindPopup(popup_586eccad65f6c89d44e8e84bb8161239)
#         ;
#
#
#
#
#             var marker_057cdcb1ab04286a4971d7e1e8b59421 = L.marker(
#                 [47.4179936, 8.3754652],
#                 {}
#             ).addTo(map_94f113657312670a2a779182fcdf7dea);
#
#
#         var popup_c9de556c741741d87bd3610032c10519 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot

# %%
# Query the SQL-table

cursor.execute('''SELECT * FROM vendors_table 
                  WHERE brand == "Volvo"''')

df_volvo = pd.DataFrame(cursor.fetchall(), 
                  columns=['lat','lon','brand','housenumber', 'street', 'name'])    
print(df_volvo)
# Out:
#          lat       lon  brand housenumber            street  \
# 0  47.190774  7.553083  Volvo           1     Aesplistrasse
# 1  47.417994  8.375465  Volvo         148       Landstrasse
# 2  47.400966  8.614925  Volvo          11     In Huebwiesen
# 3  47.493583  8.274431  Volvo           1  Studacherstrasse
#
#                      name
# 0        Viatte-Straub AG
# 1            Kreuz-Garage
# 2  Häusermann City Garage
# 3   Stocker Automobile AG

# %%
# Create map
map = folium.Map(df_volvo=[df_volvo.lat.mean(), 
                           df_volvo.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, df_volvo_info in df_volvo.iterrows():
    folium.Marker([df_volvo_info["lat"], 
                   df_volvo_info["lon"]], 
                  popup=df_volvo_info["name"]).add_to(map)

# Plot map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae5b2ffad701a06a3c637b64d3bc5109 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae5b2ffad701a06a3c637b64d3bc5109&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ae5b2ffad701a06a3c637b64d3bc5109 = L.map(
#                 &quot;map_ae5b2ffad701a06a3c637b64d3bc5109&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     dfVolvo: [47.375828975000005, 8.204476025],
#                 }
#             );
#             L.control.scale().addTo(map_ae5b2ffad701a06a3c637b64d3bc5109);
#
#
#
#
#
#             var tile_layer_f78e62b662f2f982097fcd0aa47380fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ae5b2ffad701a06a3c637b64d3bc5109);
#
#
#             var marker_9d60131b910e74e5442389b67d9d6cbe = L.marker(
#                 [47.1907736, 7.5530826],
#                 {}
#             ).addTo(map_ae5b2ffad701a06a3c637b64d3bc5109);
#
#
#         var popup_0eefad70368d88bc03e4746436200a7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a3a2b7ad203495c8ccd5010ac556de1d = $(`&lt;div id=&quot;html_a3a2b7ad203495c8ccd5010ac556de1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viatte-Straub AG&lt;/div&gt;`)[0];
#             popup_0eefad70368d88bc03e4746436200a7f.setContent(html_a3a2b7ad203495c8ccd5010ac556de1d);
#
#
#         marker_9d60131b910e74e5442389b67d9d6cbe.bindPopup(popup_0eefad70368d88bc03e4746436200a7f)
#         ;
#
#
#
#
#             var marker_de667a39136b57a5c935d6f647e9f293 = L.marker(
#                 [47.4179936, 8.3754652],
#                 {}
#             ).addTo(map_ae5b2ffad701a06a3c637b64d3bc5109);
#
#
#         var popup_33ec327a0816b05459474bf763ae72c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_26e09fd602e40419940f34c5e12cc077 = $(`&lt;div id=&quot;html_26e09fd602e40419940f34c5e12cc077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kreuz-Garage&lt;/div&gt;`)[0];
#             popup_33ec327a0816b05459474bf763ae72c7.setContent(html_26e09fd602e40419940f34c5e12cc077);
#
#
#         marker_de667a39136b57a5c935d6f647e9f293.bindPopup(popup_33ec327a0816b05459474bf763ae72c7)
#         ;
#
#
#
#
#             var marker_f7ccd8329eb5f64097148e143e61990d = L.marker(
#                 [47.4009657, 8.614925],
#                 {}
#             ).addTo(map_ae5b2ffad701a06a3c637b64d3bc5109);
#
#
#         var popup_dac25d2462b81c59ac10de88f6a2f2e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_85fc86c5444f9286a79ea4cabf080b90 = $(`&lt;div id=&quot;html_85fc86c5444f9286a79ea4cabf080b90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Häusermann City Garage&lt;/div&gt;`)[0];
#             popup_dac25d2462b81c59ac10de88f6a2f2e0.setContent(html_85fc86c5444f9286a79ea4cabf080b90);
#
#
#         marker_f7ccd8329eb5f64097148e143e61990d.bindPopup(popup_dac25d2462b81c59ac10de88f6a2f2e0)
#         ;
#
#
#
#
#             var marker_d32ce498cce33035a5b2d02543f6e077 = L.marker(
#                 [47.493583, 8.2744313],
#                 {}
#             ).addTo(map_ae5b2ffad701a06a3c637b64d3bc5109);
#
#
#         var popup_f95938dcca04cc55655beb3df5495b95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cc8f36402f5ba53dd0e3e28db8d7b432 = $(`&lt;div id=&quot;html_cc8f36402f5ba53dd0e3e28db8d7b432&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stocker Automobile AG&lt;/div&gt;`)[0];
#             popup_f95938dcca04cc55655beb3df5495b95.setContent(html_cc8f36402f5ba53dd0e3e28db8d7b432);
#
#
#         marker_d32ce498cce33035a5b2d02543f6e077.bindPopup(popup_f95938dcca04cc55655beb3df5495b95)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
